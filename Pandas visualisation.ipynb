# %%
import pandas as pd
import numpy as np
import seaborn as sb
students = pd.read_csv('D:\Костя\Downloads\StudentsPerformance.csv') #читаем табличку
# Out:
#               x            y
# 0   1211.723948  1212.918656
# 1   1205.439384  1190.471594
# 2   1198.694928  1200.830650
# 3   1190.824133  1198.465696
# 4    899.850043  1500.844311
# 5   1195.912374  1193.799239
# 6    893.919046  1502.219347
# 7    609.190101   487.890482
# 8   1186.942855  1211.467422
# 9    899.494563  1518.125089
# 10  1192.528719  1212.388023
# 11   598.748383   506.676064
# 12   897.261914  1499.901892
# 13  1193.239200  1206.182546
# 14   595.033134   500.536609
# 15   910.461620  1497.236191
# 16   609.433783   507.896377
# 17   607.459214   508.394202
# 18   896.010835  1503.455981
# 19   901.966553  1487.845050
# 20   890.483469  1495.192051
# 21   582.750903   496.645729
# 22   904.390942  1501.108230
# 23   599.876249   504.639034
# 24  1215.899432  1185.622961
# 25   600.290716   504.233086
# 26  1189.634729  1197.924099
# 27   618.157031   497.293295
# 28   604.880768   500.567315
# 29   911.220234  1488.861437

# %%
students['math score'].hist()
# Out:
# <AxesSubplot:>

# %%
#корелляция math score и reading score
students.plot.scatter(x = 'math score', y = 'reading score')
# Out:
# <AxesSubplot:xlabel='math score', ylabel='reading score'>

# %%
sb.lmplot(x = 'math score', y = 'reading score', data = students, hue = 'gender')
#hue = '<группирующая переменная>'
#Если регрессионная прямая не нужна - fit_reg = False
